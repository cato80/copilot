# %% [markdown]
# ##### Vitesse supraluminique
#
# J'ai conçu une vitesse supraluminique, c'est-à-dire une vitesse supérieure à la vitesse de la lumière, impossible dans le cadre de la théorie de la relativité de Einstein.

# %%
show(LatexExpr(r" Vitesse \ de \ la \ lumière : c=299792458 m/s"))
# Out:
#  Vitesse \ de \ la \ lumière : c=299792458 m/s

# %%
show(LatexExpr(r"Ma \ Vitesse \ supraluminique  : ç=314159265.3"))
# Out:
# Ma \ Vitesse \ supraluminique  : ç=314159265.3

# %% [markdown]
# J'explique ces 2 points de vue, le mien $ç$ que j'appelle chiracécité (vitesse chirale, pouvoir rotatoire) et $c$ célérité,vitesse scientifique. La célérité $c$ dans le vide.
#
# Je pense que la meilleure physique qui existe est la génèse :
#
# Le Bon Dieu dit : Que la lumière soit... Et la lumière fût !
#
# Depuis 10000 environ jusqu'en 1905, la terminalogie scientifique venait des religions puis de la philo, pour finir par un langage hégémonique anglo-saxons qui n'explique en rien, l'origine des symboles grecques utilisés. Aujourd'hui la symbolique est mathématique moderne, celui qui ne l'a pas apprise à peu de chance de comprendre les équations, ce qui n'était pas le cas en 1955, lorsque j'ai commencé à comprendre le sujet !

# %%
show(LatexExpr(r"Equation \ de \ la \ célérité : c=299792458 m/s"))

show(LatexExpr(r"c=\frac{1}{\sqrt\mu \epsilon}=299792458 m/s"))
# Out:
# Equation \ de \ la \ célérité : c=299792458 m/s
# c=\frac{1}{\sqrt\mu \epsilon}=299792458 m/s

# %% [markdown]
# $c$ est la célérité ou vitesse de la lumière
#
# $\mu$ symbol grecque pour la perméabilité de l'espace, un genre d'action , de force (on verra plus loin que je le traduis par une tension électrique : Volt=Force).
#
# $\epsilon$ symbol grecque pour la permitivité de l'espace, un genre de réaction, de poids (on verra plus loin que je le traduis par une intensité électrique : Ampère=Force)
#
# Quand on a une tension (U) par une intensité (I) on obtiens une résistance $R$ unité $\Omega$=Ohms. En électricité alternative plus/moins=  $\pm$, le terme est impédance $Z$ en Ohm également. $R=\frac{U}{I}$

# %%
show(LatexExpr(r"c=\frac{1}{\sqrt\mu \epsilon}=299792458 m/s"))
# Out:
# c=\frac{1}{\sqrt\mu \epsilon}=299792458 m/s

# %% [markdown]
# Côté scientifique tout le monde est content de $c$, sauf moi, car $c$ n'est pas une vitesse ! $c$ est une fréquence angulaire, c'est-à-dire une vitesse/fréquence de rotation, mieux : Une seconde équation analogue à $c$ correspond à la circonférence du cercle !
#
# $c_v=\pi 2 f$ en remplaçant $f$ par $c$ on a la formule de la circonférence du cercle $c_i=\pi 2 r$, comment 120 ans de physique ont pu jeter un voile sur ces formules ?
#
# Comme circonstance atténuante, je leurs concède que la formule ne s'écrit pas exactement comme ça, elle s'écrit:
#
# $2 \pi f$, oubliant leurs leçons du primaire, n'ont ils peut être pas fait le lien ?
#
# En plus à leur décharge $c=\omega$, donc ils apprennent à l'université, la forme $w=2\pi f$ et non $c=2\pi f$, la forme de terminale et d'université est $c=\frac{1}{\sqrt\mu \epsilon}$, donc $c=w=2 \pi f=c=\frac{1}{\sqrt\mu \epsilon}$
#
# Ce qui me fait dire que Einstein a réinventé la roue avec la relativité !
#
# Morale de l'histoire : je recherche la raison d'une telle gabegie ?
#
# Un difficulté supplémentaire : Les Relativés (RR et RG) sont devenues un dogme, aucun intellectuel n'irait risqué sa réputation en émettant un doute, dans les années 1920, ceux qui l'ont fait s'en sont mordus les doigts !
#
# Je recherche la vérité et l'honnêté, je me dois déontologiquement d'exposer ce que je pense à ceux que ça intérêsse !

# %% [markdown]
# ###### Le pourquoi de ma recherche
#
# En analysant les formules de la relativité, j'ai fini par m'apercevoir qu'il y avait une contradiction (pour ne pas dire une erreur), dans sa terminalogie et ses maths.
#
# La première loi d'Einstein dit que la vitesse de la lumière est une vitesse limite, qui ne peut être franchie ou égalée par une particule de masse, donc $m < c$ (la masse est toujours inférieure à c) .
#
# Pourtant il utilise sa fameuse équation : $E=mc^2$, où la quantité $c^2$ est supérieure à c (m>c) !
#
# $c=299792458$ m/s  et $c^2=89875517873681764$m/s
#
# En clair projetons une pierre (En allemand une pierre = ein Stein) ! lol, à la vitesse $c$ et à la vitesse $c^2$, laquelle est la plus rapide ?
#
# Cette simple description peut être comprise par un enfant de 9 ans !
#
# $c^2= a$ accélération, pour des matheux, la vitesse et l'accélération sont deux choses bien différentes, qui ne nous concernent pas en ce moment, mais il faudra y venir.
#
# C'est le départ de ma recherche : Comment exprimer l'erreur, afin qu'elle soit compréhensible scientifiquement par tout un chacun.

# %%
c=299792458;cc=c*c
show(LatexExpr(r"c^2=\frac{1}{\mu \epsilon}="),cc," m/s")
# Out:
# c^2=\frac{1}{\mu \epsilon}= 89875517873681764 ' m/s'

# %% [markdown]
# Voici la correction que j'apporte à la vitesse de la lumière qui devient une possible vitesse supraluminique.
#
# ###### Précision sur vitesse de la lumière
#
# La vitesse de la lumière $c$ n'est pas une vitesse, d'ailleurs les scientifiques utilisent de moins en moins ce terme, ils y préferrent le terme de vitesse de particule et dans le cas du photon (particule de lumière "quanta") vitesse du photon. Je pense qu'ils sont de plus en plus complexés, troublés, à dire vitesse de la lumière car en fait la lumière n'est pas une vitesse, Einstein a du rater son école primaire (d'ailleurs c'est ce qui est dit) et il a mal compris la notion de vitesse ?

# %% [markdown]
# La célérité $c$ est une constante donc une constante n'a pas de dérivé et comme une vitesse est une dérivée, $c$ ne peut pas être une vitesse. Cette phrase est importante car elle souligne toute l'ampleur de l'erreur.
#
# $c=299792458$ constante. (position)
#
# $c^2=89875517873681764$ accélération (opération intégrale)
#
# $2c=599584916$ vitesse (opération dérivée)
#
# A aucun moment dans les livres ou cours sur la Relativité, je n'ai vu $2c$ comme étant une vitesse, ce qui signifie que tous les profs de maths, les scientifiques sont passés à côté d'une telle définition qui pourtant était enseigné en 6ième dans les années 1960, d'ailleurs c'est ce qui m'a valu de ne pas avoir les bourses pour le collège, pour l'entré en 6ième ?

# %%
299792458*2
# Out:
# 599584916

# %% [markdown]
# Un peu de rappel sur le calcul infinitésimal : position, vitesse, accélération, constante
#
# J'utilise le logiciel sage (sagemath) libre et gratuit, très performant. Avec ça j'ai sous la main toutes les fonctions de base de calcul, important quand on ne les a pas apprises, pas fait le collège ou qu'on a oublié ses études de collèges.

# %%
# %display latex
var("c")  # Définir affecter une variable ici c célérité
solve(c^2==x^2,x) # Preuve de deux lumières deux célérités
# Out:
# [x == -c, x == c]

# %% [markdown]
# ##### Pour calculer la vitesse, la dérivée de $c^2$

# %%
v=diff(c^2);v
# Out:
# 2*c

# %% [markdown]
# La vitesse de la lumière devrait être $2c$ et non $c$ !
#
# Ainsi la célérité $c$ est bien une constante et pas une vitesse (une dérivé), la constante devrait être c=0 !
#
# Dans le cas de la lumière en fait elle est la position c=299792458.
#
# Morale de l'histoire : Ce fût la génèse de mes cogitations, qui commencèrent à 9 ans et me pertubèrent longtemps ne trouvant pas de solutions à l'époque ! C'était des intuitions... Et le début d'une longue recherche :
#
# ### RESONANCIA CATOLICA
# ### LA RESONANCE UNIVERSELLE
