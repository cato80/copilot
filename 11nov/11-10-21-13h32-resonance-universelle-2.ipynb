# %% [markdown]
# ##### Resonancia catolica
#
# Mon concept de résonance universelle (théorie), vient du fait qu'il manque en physique des entités, telle que l'éther qui a été banni par un manque de sa compréhension des physiciens du siècle dernier.
#
# Dans l'article précédent j'avais expliqué les erreurs de la Relativité, qui ne permettait pas une vitesse supérieure à la célérité, je comble avec ç (chiracécité=chiral invisible, donc une deuxième lumière positive celle-ci par contre, puisque Einstein introduit la célérité en signature négative : +++-  =x+y+z-c, alors que j'introduis une signature positive : ++++ = x+y+z+ç, pas particulièrement important dans notre cas, c'est de la théorie.
#
# Voici mes équations qui changent pas mal de choses :
#
# L= Inductance (bobine)du milieu (correspond à la perméabilité du vide dans la célérité c)
#
# C= Capacitance(condensateur) du milieu, permitivité dans c
#
# ç= Fréquence angulaire (célérité scientifique)
#
# La formule ne change pas, seules les noms et les valeurs de variables changent, pour éviter une confusion, mais j'aurais pu garder les mêmes termes !
#
# $ç=\frac{1}{\sqrt L C}=314159265$
#
# J'ai du concevoir des valeurs possibles, pour avoir une certaine crédibilité, au début j'ai écrit les équations sans trop savoir ce qu'elles représentaient et petit à petit j'ai compris leur signification.

# %%
show(LatexExpr(r"Valeur \ de \ l'inductance :"))
show(LatexExpr(r"L=0.00000114591559026165"))
# Out:
# Valeur \ de \ l'inductance :
# L=0.00000114591559026165

# %%
L=1/n(pi)*360E-8;L
# Out:
# 1.14591559026165e-6

# %%
show(LatexExpr(r"Valeur \ de \ la \ capacitance :"))
show(LatexExpr(r"C=0.00000000000884194128288307"))
# Out:
# Valeur \ de \ la \ capacitance :
# C=0.00000000000884194128288307

# %%
C=1/(n(pi)*360E+8);C
# Out:
# 8.84194128288307e-12

# %%
show(LatexExpr(r"Valeur \ de \ la \ chiracécité : ç "))
show(LatexExpr(r"ç=\frac{1}{\sqrt L C}=314159265"))
# Out:
# Valeur \ de \ la \ chiracécité : ç
# ç=\frac{1}{\sqrt L C}=314159265

# %%
ç=1/sqrt(L*C);int(ç)
# Out:
# 314159265

# %%
show(LatexExpr(r"Valeur \ de \ la \ perméabilité : \mu "))
show(LatexExpr(r"\mu=0.00000012566370614"))
# Out:
# Valeur \ de \ la \ perméabilité : \mu
# \mu=0.00000012566370614

# %%
show(LatexExpr(r"Valeur \ de \ la \ permittivité : \epsilon "))
show(LatexExpr(r"\epsilon=0.00000000000885418782"))
# Out:
# Valeur \ de \ la \ permittivité : \epsilon
# \epsilon=0.00000000000885418782

# %% [markdown]
# Manier des décimaux de cette grande taille peut entrainer des erreurs, donc j'ai pris l'habitude d'utiliser l'inverse, avec certains avantages
#
# Par exemple, l'inverse de la lumière est l'indice de réfraction $n=\frac{1}{c}$. L'inverse de $\mu$ égale 795774.715608873, on a une meilleure vue de la grandeur de cette constante, puisque elle va donner directement $\frac{1}{c^2}=\mu\epsilon$

# %% [markdown]
# Ampère = 0.0000002 Newton, 0.000002 kg

# %%
1/0.000002 # ? 2000 ampères égale 1000 tonnes
# Out:
# 500000.000000000

# %%
2*1000.000 # mille tonnes égale 2000 ampères
# Out:
# 2000.00000000000

# %%
mu=4*3.141592653E-7;mu
# Out:
# 1.25663706120000e-6

# %%
int(1/mu)
# Out:
# 795774

# %%
epsilon=1/(mu*299792458^2);epsilon
# Out:
# 8.85418781928265e-12

# %%
int(1/epsilon)
# Out:
# 112940906654

# %%
795774*112940906654
# Out:
# 89875437051680196

# %%
c=299792458;c^2
# Out:
# 89875517873681764

# %%
sqrt(89875437051680196.0)
# Out:
# 2.9979232320338057e8

# %%
epsilon*mu
# Out:
# 1.11265005605362e-17

# %%
1/sqrt(epsilon*mu)
# Out:
# 2.99792458000000e8

# %%
epsilon/mu
# Out:
# 7.04593879383720e-6

# %%
mu*epsilon/c^2
# Out:
# 1.23799014723612e-34

# %% [markdown]
# 2 ampères égale une tonne
