# %% [markdown]
# https://fr.wikipedia.org/wiki/Supraconductivit%C3%A9

# %% [markdown]
# ###### Théorie de $\pi \times \pi \times k \times k \pm 1$
#
# En langage nouvel humain : théorie du pipi caca boudin !

# %% [markdown]
# ##### Science obsolète
#
# Trop d'erreurs sont commises au nom de la science, je veux apporter ma contribution universelle à la correction de certaines et pouvoir progresser avec de nouvelles bases.

# %%
8/8.1
# Out:
# 0.987654320987654

# %% [markdown]
# Base 10 : Cette suite des chiffres décimaux moins le 1, multiplier par 10, est le carré de $\pi$ au centième.

# %%
p=sqrt((8/8.1)*10);p
# Out:
# 3.14269680527354

# %%
1-(n(pi)/p)
# Out:
# 0.000351338914367672

# %% [markdown]
# La série donne $\pi$ exacte au millième, largement plus précis que ce qu'on a besoin au quotidien ?
#
# On voit que $\pi$ est déterminé par la base 10.
