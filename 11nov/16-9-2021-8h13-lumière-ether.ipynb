# %% [markdown]
# ###### Pouvoir rotatoire
#
# Un cercle est une déformation d'une droite, déterminée par une constante, ou base. Le cas de la base 10 est frappante :
# 0123456789, qui peut être obtenu simplement par :

# %%
8/8.1 # fausse base 10 vrai base 8
# Out:
# 0.987654320987654

# %%
sqrt(9.87) # pi au millième
# Out:
# 3.14165561448100

# %%
p=plot(sqrt(1-x^2),x,-1,1);
show(p,aspect_ratio=1,figsize=2,fontsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
q=plot(-sqrt(1-x^2),x,-1,1,color="red");
show(q,aspect_ratio=1,figsize=2,fontsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
c=299792458;cc=c^2
Co=cc/1E+7;int(Co),int(cc)
# Out:
# (8987551787, 89875517873681764)

# %% [markdown]
# La lumière possède 2 charges qui s'attirent et se repoussent de $c^2$ donc de 89875517873681764 N/s et  A/s
#
# 8987551787368176.4 kg
#
# D'où un poids en Force/Masse/Tonnes :8987551787368.1764 T

# %%
e =1.602E-19;ec=89875517873681764*e;ec
# Out:
# 0.0143980579633638

# %% [markdown]
# La charge éléctrique d'un photon est $ec=0.0143980579633638 C$

# %%
1/ec # pour 1Coulomb
# Out:
# 69.4538112393020

# %% [markdown]
# Ce qui montre qu'il faut nettement moins de photons pour faire 1C alors qu'il faut 6.242E+18 électrons pour 1C

# %% [markdown]
# http://arsene.perez-mas.pagesperso-orange.fr/physique/electricite/statique/Statique05_ChampElectrique.htm
#
# ##### Définition d'un champ életrique
#
# Champ électrique produit pas une particule q
