# %% [markdown]
# La formule de la lumière est une conductance et non une vitesse.
#
# C'est pourquoi  la célérité n'est pas une vitesse limite : La vitesse limite est quand la résistance, l'impédance du vide est égale à 360°, c'est à dire quand la célérité est égale à la résonance :$X=X_L-X_C$
#
# réatance > réaction  conductance > action
#
# c'est au moment de la résonance que l'énergie est transférée à la lumière, donc la résonance est le rayon de la célérité. C'est le moment de la pulsation. C'est l'expulsion de l'énergie, donc une vitesse plus élevée, il ne faut pas oublié que la vitesse est une moyenne. Dans le cas de $c$ la vitesse est la racine carrée de l'accélération. Ce n'est pas une dérivée qui serait $2c$. La dérivée est le diamètre de la résonance 0.5*2 =1

# %%
w=n(pi,digits=2);f=w/(2*n(pi));

# %%
f*2
# Out:
# 1.0

# %% [markdown]
# La pulsation est la circonférence du cercle ($\pi$) et la fréquence de résonance est le rayon. $r+r=d$, quand $r=0.5$), formule : $\pi r2$)

# %%
show(LatexExpr(r"w=c=2\pi \nu"))
# Out:
# w=c=2\pi \nu

# %%
show(LatexExpr(r"c=\frac{1}{\sqrt \mu \epsilon}=w"))
# Out:
# c=\frac{1}{\sqrt \mu \epsilon}=w

# %% [markdown]
# La célérité n'est pas un cercle fermé : Il existe un comma entre $\frac {ç}{c}$ qui est la lumière ou l'éther ?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1/(256.0/243)
# Out:
# 0.949218750000000

# %%
1+2+3+4+5+6+7+8
# Out:
# 36

# %%
314159265.3/299792458
# Out:
# 1.04792251077911

# %% [markdown]
# La physique est obsolète, les particules n'existent pas, ce sont des rapports d'intervals compressés, des aires ramenées à leur plus simple expressions.

# %%
299792458*1.04792251077911
# Out:
# 3.14159265300001e8

# %%
v=299792458;u=n(pi)*4E-7;s=1/(u*v*v);s
# Out:
# 8.85418781762039e-12

# %%
1/u,1/s
# Out:
# (795774.715459477, 1.12940906675815e11)

# %%
2/sqrt(n(pi))
# Out:
# 1.12837916709551

# %%
1.12940906675815/1.12837916709551
# Out:
# 1.00091272481155

# %%
1/(2/sqrt(n(pi)))
# Out:
# 0.886226925452758

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
deg(1/(2/sqrt(n(pi))))
# Out:
# 50.7770625192981

# %%
deg(0.885418781762039)
# Out:
# 50.7307592965797

# %%
deg(0.884)
# Out:
# 50.6494690895648

# %%
deg(0.949218750000000)
# Out:
# 54.3862282096836

# %%
deg(0.650)
# Out:
# 37.2422566835035

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
