# %% [markdown]
# ###### Le complexe yin yang
#
# Quand le psi rejoint le matheux : Complexe d'oedipe/Complexe imaginaire !
#
# Freud n'était sans doute pas matheux et il n'aurait jamais imaginé que ce genre d'invididu possédait un complexe du nombre imaginaire ?
#
# De même, je suppose qu'il n'aurait sans doute jamais imaginé que son complexe d'oedipe prenne pied dans la réalité (oedipus rex règne), quand la fiction dépasse la réalité !

# %%
# %display latex
show(LatexExpr(r"i=\sqrt-1"));i
# Out:
# i=\sqrt-1
# I

# %%
var("y")
dx=-x/2.5;df=plot(dx,x,-2.5,2.5,color="brown")
dn=-x*2.5;ni=plot(dn,x,-1,1,color="orange")
d1=x/2.5;n1=plot(d1,x,-2.5,2.5,color="green")
d2=x*2.5;n2=plot(d2,x,-1.,1.,color="violet")
ce=circle((0,0),2.7,color="red")
ci=circle((0,0),2,color="black")
h = implicit_plot(x^2+y^2-8,(-3,3),(-3,3),plot_points=4)
show(h+ce+ni+n1+ni+n2+ci+df,figsize=4,axes=False,
aspect_ratio=1,gridlines=True,frame=False,fontsize=6)
# Out:
# Graphics object consisting of 8 graphics primitives
