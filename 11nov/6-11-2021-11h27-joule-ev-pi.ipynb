# %% [markdown]
# https://fr.wikipedia.org/wiki/Joule
#
# If faut utiliser $pi$ comme référentiel des constantes. Donc les convertir dans les multiples ou sous multiples de $\pi$, on ne peut pas vraiment dire que ça change quelque chose, mais l'avantage est le référentiel stable de $\pi$ qui peut même être calculé à partir de la base 10 : $\pi^2$=9.876543210
#
# La racine carrée donne 3.14 ! largement suffisant dans le quotidien.

# %%
J1=n(pi)*2E18;J1
# Out:
# 6.28318530717959e18

# %%
eV=1/J1;eV
# Out:
# 1.59154943091895e-19

# %%
kg=9.876543210 # 10 Newton = 1Joule

# %% [markdown]
# un joule est le travail fourni par un circuit électrique pour faire circuler un courant électrique d'un ampère à travers une résistance d'un ohm pendant une seconde :
#
#     1 J = 1 Ω A2 s = 1 W s = 1 kg m2 s−2
#
# 1 Watt= 1V*1A  1Ohm=1V/1A  1V=1A/1Ohm  1A=1V*1Ohm

# %%
# %display latex
n(pi,digits=40)
# Out:
# 3.141592653589793238462643383279502884197

# %%
31415926535897932384626433832795029/\
10000000000000000000000000000000000
# Out:
# 31415926535897932384626433832795029/10000000000000000000000000000000000

# %%
314159265358979323846264338327950/\
100000000000000000000000000000000
# Out:
# 6283185307179586476925286766559/2000000000000000000000000000000

# %%
3141592653589793238462643383279502/\
10000000000000000000000000000000000
# Out:
# 1570796326794896619231321691639751/5000000000000000000000000000000000

# %%
314159265358979323846264338327950288/\
1000000000000000000000000000000000000  # 2884197
# Out:
# 19634954084936207740391521145496893/62500000000000000000000000000000000

# %%
3141592653589793238462643383279502884/\
1000000000000000000000000000000000000 # 2884197
# Out:
# 785398163397448309615660845819875721/250000000000000000000000000000000000

# %%
31415926535897932384626433832795028841/\
10000000000000000000000000000000000000  # 2884197
# Out:
# 31415926535897932384626433832795028841/10000000000000000000000000000000000000
