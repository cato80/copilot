# %%
var("omega")
R=0.001;L=0.001;C=0.885;w=round(1/(sqrt(L*C)),2);
p=plot(abs(1/(1+i*omega*R*C-omega*omega*L*C)),
       [omega,0,2*w],color="darkgreen")
f=w;r=R;c=C;l=L
lbl = text("$w_r = %.0f rad/s$" % f,(4,10),
           rgbcolor="darkgreen",
           horizontal_alignment="left",
           fontsize=10,
           bounding_box={'boxstyle':'round',\
                         'fc':'w'})
show(p+lbl,figsize=3,frame=True,axes=False,
     gridlines="minor",fontsize=6,
     gridlinesstyle=dict(color="lightsalmon",
                         linestyle="-",alpha=0.4,
                         linewidth="0.5"))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# 1/(1+i*omega*R*C-omega*omega*L*C

# %%
show(LatexExpr(r"\frac{1}{1+i\omega R C-\omega^2 L C}"))
# Out:
# \frac{1}{1+i\omega R C-\omega^2 L C}

# %%
var("omega")
R=0.001;L=0.001;C=0.885;w=1/(sqrt(L*C));
fr=1/(2*pi*sqrt(L*C))
q=plot(abs(1/(1+i*2*pi*omega*R*C\
              -omega*2*pi*omega*2*pi*L*C)),
       [omega,0,2*fr],color="darkorange")
#f=w;r=R;c=C;l=L
lbl = text("$f_r = %.0f Hz$" % (fr),(0.6,8),
           rgbcolor="darkgreen",
           horizontal_alignment="left",
           fontsize=10,
           bounding_box={'boxstyle':'round',\
                         'fc':'w'})
show(q+lbl,figsize=3,frame=True,axes=False,
     gridlines="minor",fontsize=6,
     gridlinesstyle=dict(color="lightgreen",
                         linestyle="-",alpha=0.4,
                         linewidth="0.5"))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# 1Hz=2 pi rad/s  1rad/s= 1/6.28=0.1591549Hz

# %%
show(LatexExpr(r"\frac{1}{1+i 2 \pi \omega R C- 4 \pi^2  \omega^2 L C}"))
# Out:
# \frac{1}{1+i 2 \pi \omega R C- 4 \pi^2  \omega^2 L C}

# %%
hz(x)=x*2*n(pi);hz(5)
# Out:
# 31.4159265358979

# %%
raz(x)=x*1/(2*n(pi));raz(34)
# Out:
# 5.41126806512444

# %%
rad(x)=x*n(pi)/180;rad(5.41)
# Out:
# 0.0944223125328932

# %%
deg(x)=x*180/n(pi);deg(2*n(pi))
# Out:
# 360.000000000000

# %%
deg(5.41)
# Out:
# 309.970167165775

# %%
2*n(pi)/60
# Out:
# 0.104719755119660

# %%
299792548*0.104719755119660
# Out:
# 3.13942022132589e7

# %%
3.141592653-3.13942022132589
# Out:
# 0.00217243167411008

# %%
3.141592653/3.13942022132589
# Out:
# 1.00069198499116

# %%
3.141592653/2.99792548;deg(1.04792219618481)
# Out:
# 60.0415190994699

# %% [markdown]
# 1Hz=6.28 rad/s=360°=3.141592653
#
# Période 2 pics  fréquence 2 intervalles
#
# Longueur d'onde = distance d'une période

# %%
c=299792458;cc=c^2;cc # c*c photon
# Out:
# 89875517873681764

# %%
1.0/cc
# Out:
# 1.11265005605362e-17

# %%
int(cc/10000000.0) # Coulomb en Newton électron
# Out:
# 8987551787
