# %% [markdown]
# ###### Lumière Ether
#
# 1Hz=6.28 rad/s=360°=3.141592653

# %%
# %display latex
c=299792458;rads=1/(2*n(pi));rads
# Out:
# 0.159154943091895

# %%
fr=c*rads;fr# fréquence de résonance de la lumière
# Out:
# 4.77134515923694e7

# %%
ç=314159265.4*rads # fréquence de résonance
# Out:
# 5.00000000065286e7

# %% [markdown]
# La différence entre la période et la fréquence est un déphasage de $\pi$

# %%
hz=2*n(pi);hz
# Out:
# 6.28318530717959

# %% [markdown]
# La longueur d'onde et la fréquence (en rad/s) sont identiques, la différence est par quel bout on commence !

# %%
show(LatexExpr(r"Hz=2 \pi \ rad^{-1s}"))
# Out:
# Hz=2 \pi \ rad^{-1s}

# %%
show(LatexExpr(r"Hz=2 \pi \ rad^{-1s} \ et \ \lambda=2\pi"))
# Out:
# Hz=2 \pi \ rad^{-1s} \ et \ \lambda=2\pi

# %%
c=1;f=2*pi;lo=c/f;lo
# Out:
# 1/2/pi

# %%
deg(x)=x*180/n(pi);deg(1/2*n(pi))
# Out:
# 90.0000000000000

# %%
rad(x)=x*n(pi)/180;rad(90)
# Out:
# 1.57079632679490

# %%
deg(x)=x*180/n(pi);deg(0.159154943091895)
# Out:
# 9.11890652781038

# %%
deg(x)=x*180/n(pi);deg(1/0.1591549430918955)
# Out:
# 360.000000000000

# %%
deg(x)=x*180/n(pi);deg(0.105) # 1 tour minute
# Out:
# 6.01605684887364

# %%
rad(x)=x*n(pi)/180;rad(6)
# Out:
#   File "C:\Users\henri\AppData\Local\Temp/ipykernel_6636/1105063089.py", line 1
#     rad(x)=x*n(pi)/180;rad(6)
#     ^
# SyntaxError: cannot assign to function call
