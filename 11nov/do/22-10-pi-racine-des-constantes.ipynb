# %% [markdown]
# Toutes les constantes en physique sont multiples ou sous-multiples de $\pi$

# %%
show(LatexExpr(r""))
# Out:
# \begin{math}
# \newcommand{\Bold}[1]{\mathbf{#1}}
# \end{math}

# %% [markdown]
# carré égale Ep*Ek      $E=c^2$
#
# racine carrée égale Ep et Ek
