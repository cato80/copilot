# %% [markdown]
# ##### Version électronique de la circonférence
#
# La circonférence du cercle $c=\pi r2$ est égale à $\omega=\pi f2$ ou $w=2\pi\nu$.

# %%
# %display latex
r=2;c=pi*r;c
# Out:
# 2*pi

# %% [markdown]
# Ainsi la longueur d'onde fondamentale est $2\pi=6.28$
#
# Les scientifiques ont assimilé la célérité $c$ à la circonférence $\lambda$.

# %%
show(LatexExpr(r"\lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}} = \frac{c}{\nu}=2\p}{\frac{1}{2\pi\sqrt\mu\epsilon}} = \frac{c}{\nu}=2\pi"))
# Out:
# \lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}} = \frac{c}{\nu}=2\p}{\frac{1}{2\pi\sqrt\mu\epsilon}} = \frac{c}{\nu}=2\pi

# %% [markdown]
# La vraie valeur non polarisé de $c=\frac{1}{\sqrt\mu\epsilon}=314159265=ç$

# %%
L=1/n(pi)*360E-8;C=1/(n(pi)*360E+8);
ç=1/sqrt(L*C);round(ç,8)
# Out:
# 314159265.35897934

# %%
show(LatexExpr(r"ç=\frac{1}{\sqrt L C }=314159265"))
# Out:
# ç=\frac{1}{\sqrt L C }=314159265

# %% [markdown]
# Valeur scientifique de $c$, avec la coudée du pied du roi

# %%
rr=2/sqrt(n(pi));f(x)=sqrt(rr^2-x^2);base=439.995154;round(base,6)
# Out:
# 439.995154

# %%
# valeur cercle circonscrit
c=n(pi)/6;r=sqrt(2.0);cp=c*r*n(pi)*439.995154;cp
# Out:
# 1023.55547608840

# %%
# cercle inscrit
cr=n(pi)/6;rp=c*n(pi)*439.995154;rp
# Out:
# 723.763018062732

# %%
# coudée du pied du roi
cc=439.995154;ll=cr*cc*r*n(pi);ll
# Out:
# 1023.55547608840

# %%
# vc
lc=cr*cc*n(pi);((ll-lc))
# Out:
# 299.792458025667

# %% [markdown]
# Il est important de voir que la vitesse de la lumière est en nano métres

# %%
cr=circle((0,0),sqrt(2),color="black")
ci=circle((0,0),1,color="red");ic=circle((0,0),1.4141,color="green")
po=polygon([(1,1),(-1,1),(-1,-1), (1,-1)],fill=False)
cç=circle((0,0),0.299792,color="orange")
show(po+ci+ic+cç,figsize=5,axes=False,
aspect_ratio=1,gridlines="minor",frame=True,fontsize=6)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
ll/lc
# Out:
# 1.41421356237310

# %% [markdown]
# Pourquoi une onde se créée t elle en dégradée ?
#
# Les ondes se compose à partir de l'addition ou la soustraction de 2 ondes.

# %%
c1=circle((0,0),1.628)
ce=ellipse((0,0),1.6626,1,color="red")
show(ce+c1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
c0=n(pi*2);c0
# Out:
# 6.28318530717959

# %%
z1=circle((0,0),1.360)
ze=ellipse((0,0),1.37679,1,color="red")
show(z1+ze)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Les ondes une illusion d'optique ?
#
# Si la constante de planck était de 2$\pi$E-34 (h=6.626E-34), elle serait un cercle et non une ellipse. Le pire c'est qu'elle prouve ce que je suis en train contesté. Réalité : rond, Relativité : ellipse !
# Facteur de Lorentz :
#
# $\gamma=\frac{c}{\sqrt c^2-v^2}=\frac{1}{\sqrt 1- \frac {v^2}{c^2}}=\frac{dt}{d\Gamma}=\frac{1}{\alpha} $
#
# t temps coordonnée et $\Gamma$ le temps propre. $\alpha$ est le facteur de contraction, inverse de $\gamma$
#
# Mon équation tirée du rapport $c=\frac{Em}{Qm}$ est $ç=\frac{c c }{c}$

# %%
c=314159265.3;v=299792548
a=sqrt(c^2-v^2)/c;a
# Out:
# 0.298948269369748

# %%
int(c-v) #14366.717 km/s
# Out:
# 14366717

# %% [markdown]
# ###### Pourquoi trouve-t-on la célérité $c$ dans la base de la pyramide ?
#
# Cette question est survenue après un article sur internet. J'ai essayé de trouver une réponse maths.
#
# ###### Facteur de Lorentz :
#
# $\gamma=\frac{c}{\sqrt c^2-v^2}=\frac{1}{\sqrt 1- \frac {v^2}{c^2}}=\frac{dt}{d\Gamma}=\frac{1}{\alpha} $
#
# ###### Equation de la pyramide :

# %%
base=439.995154;round(base,6)
# Out:
# 439.995154

# %%
cr=n(pi)/6;rc2=sqrt(2.0)
show("Coudée du pied du roi = ",round(cr,6))
show("Racine carrée de 2 = ",round(cr,6))
show("base= ",round(base,6))
show("Pi= ",n(pi))
r=sqrt(2.0);cp=c*r*n(pi)*439.995154
# Out:
# 'Coudée du pied du roi = ' 0.523599
# 'Racine carrée de 2 = ' 0.523599
# 'base= ' 439.995154
# 'Pi= ' 3.14159265358979

# %%
Cc=c*r*n(pi)*439.995154;
show("Cercle circonscrit= ",Cc)
# Out:
# 'Cercle circonscrit= ' 6.14133285537744e11

# %%
Ci=c*n(pi)*439.995154;
show("Cercle inscrit= ",Ci)
# Out:
# 'Cercle inscrit= ' 4.34257810756113e11

# %%
show("Différence Cc-Ci= ",round(Cc-Ci,6))
# Out:
# 'Différence Cc-Ci= ' 179875474781.6308

# %% [markdown]
# Un millionième de la célérité = 299792458
