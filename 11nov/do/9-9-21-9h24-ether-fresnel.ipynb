# %% [markdown]
# ##### Ether : Cette inconnue...
#
# Aussi loin qu'on remonte dans le temps, les hommes ont noté qu'un fluide subtil les entouraient...
#
# C'est là que le bas blesse : L'éther n'a jamais pu être détecté, car les mesures n'ont pas été faites dans la direction de ses qualités !
#
# Aujourd'hui on doit y remédier, sous peine de s'engager dans un terrain bourbeux !
#
# Ma définition de l'éther est : L'impédance du vide, dont les scientifiques donne une valeur de 376,730 $\Omega$. Mais cette valeur n'est pas fixe, elle dépend du rapport entre la perméabilité et la permitivité du vide : $\mu$ et $\epsilon$ ce qui fixe la célérité dans le vide relativiste à $c=299792548$, mais ce vide n'est pas universel, c'est un vide local, un référentiel scientifique et relativiste. On peut imaginer que le $vide = 0$, mais je le fixe par mes équations à $360°=360\Omega$, ce qui permet de donner une valeur de $1°=1\Omega$, (valeur scientifiquement fausse, puisqu'elle donne une différence de $1\Omega=14366717 $m/s, ce qui est énorme !)
#
# Par contre le rapport donne une constante intéressante $Z_r=1,047$ rad/s, qui est en degré : 60°. Divisé par 2 = 30°, due à la polarisation de la lumière mesurée, puisque celle-ci passe dans un miroir pour être mesurée.

# %% [markdown]
# De l'éther de Fresnel à la relativité restreinte page 42
#
# La lumière est polarisée de 30°ce qui baisse sa vitesse de ç à c.

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
ç=314159265.3;c=299792458
deg(ç/c)
# Out:
# 30.0207685621977

# %% [markdown]
# Dans l'espace, la lumière est polarisée, du fait de l'impédance du vide, elle est polarisée de 17 $\Omega$, différence entre un espace fermé (360°) et un espace ouvert 376.7 $\Omega$

# %%
G=1/376.7;G
# Out:
# 0.00265463233342182

# %%
rad(x)=x*n(pi)/180

# %% [markdown]
# L'Ether est la lumière non polarisée : Transparence biphoto
#
# De la transparence nait la lumière ?
#
# En une seconde la lumière perd $ç-c=14366,717km/s$

# %%
314159265-299792548
# Out:
# 14366717
