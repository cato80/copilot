# %% [markdown]
# ###### Aether be !
#
# We must come back about 700 years ago (he is born in 1320) (for the time being !), There was a french monk in solesme abbaye (Near where I live about 100 kms), can you imagine what a genius he was ?
#
# https://en.wikipedia.org/wiki/Nicole_Oresme
#
# He is the concepter of speed (axe vertical speed, axe horiz times :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# From this pic I concieved a lot of ideas, I will explain later because there is a book for it ! lol
#
# But I noticed that diagonal could be square root of 2 if I use a square ?
#
# I pass to Leibniz : 1646 (300 years difference !), it shows how spirit can quickly evolve.
#
# Reading leibniz gave me a clue about a mistake he made and a fantastic discover he made too ! :
#
# https://www.jstor.org/stable/228997
#
# He said vis visa equation is $Fs=mv^2$, so the controversy has never been cleared and fall into the bin... Unfortunatly for us as I will explain... It's not good for  science to ban ideas, because it's regressing instead evolving !

# %% [markdown]
# And the last catastrophe : Speed of light and $E=mc^2$, maybe you start to understand what I want to explain ?
#
# $Fs=E=mc^2=mv^2$
#
# Now equations ! Einstein said :
#
# https://en.wikipedia.org/wiki/Speed_of_light
#
# No particule of mass can be speeder than light ?
#
# But he used : $c^2$ which is speeder than light !
#
# So I call it Einstein's controversy !
#
# For me this error comes from $Fs=mv^2$ they should have agreed with liebniz !

# %%
c=299792458 # ms (but for me that's not a speed)
cc=c^2;cc # which is greater in one second ! $c^2=a
# Out:
# 89875517873681764

# %%
a=89875517873681764
