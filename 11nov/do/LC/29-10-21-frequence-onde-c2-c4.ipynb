# %% [markdown]
# $f_r$

# %%
red=650;ç=314159265.3
f=ç/red*1E9;round(f) # Hz
# Out:
# 483321946615385

# %% [markdown]
# Rayons X
#
# $\lambda$=1E-9 6E-12
#
# $f$ 3E+17 5E19 Hz
#
# $eV$ =12000 2400000
#
# Rayons $\gamma$
#
# f=1E+18Hz  3E+18
#
# énergie=100000 eV   10000000 eV

# %% [markdown]
# Ether=$ç^2 ç^4 ç^5$

# %%
# Bizarre ?
J=1/(n(pi));J
# Out:
# 0.318309886183791
