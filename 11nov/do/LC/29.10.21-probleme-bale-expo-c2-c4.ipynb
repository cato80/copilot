# %% [markdown]
# https://accromath.uqam.ca/2021/10/euler-et-le-probleme-de-bale/

# %%
n(pi^2)/6
# Out:
# 1.64493406684823

# %%
# %display latex
zeta(2)
# Out:
# 1/6*pi^2

# %%
1/(n(pi^2)/6)
# Out:
# 0.607927101854027

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
deg(x)=x*180/n(pi);deg(n(pi)*2)
# Out:
# 360.000000000000

# %%
show("1 HZ=",round(deg(n(pi)*2)));c=299792458
# Out:
# '1 HZ=' 360

# %% [markdown]
# Longueur d'onde = $\lambda$=c/f
#
# Radians par minutes 376.99

# %%
l=c/360.0;l*1E9
# Out:
# 8.32756827777778e14

# %%
lz=c/376;lz*1E9
# Out:
# 7.97320367021277e14

# %%
n(pi)*2*60
# Out:
# 376.991118430775

# %%
1/1.33
# Out:
# 0.751879699248120

# %%
deg(x)=x*180/n(pi);deg(0.751879699248120)
# Out:
# 43.0795334684829

# %%
z=376.5/1.5;z
# Out:
# 251.000000000000
