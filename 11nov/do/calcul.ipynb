# %%
# %display latex
expand((x+1)^2)
# Out:
# x^2 + 2*x + 1

# %%
factor(x^2-1)
# Out:
# (x + 1)*(x - 1)

# %%
solve(x^2-1>=0,x)
# Out:
# [[x <= -1], [x >= 1]]

# %%
find_root(x^5-x==1,0,2)
# Out:
# 1.1673039782614187

# %%
var("x y")
solve([x+2*y==7,x-y==1],x,y)
# Out:
# [[x == 3, y == 2]]

# %%
f(x) = 2*x^2 + 3;f(1)
# Out:
# 5

# %%
f(x+1)
# Out:
# 2*(x + 1)^2 + 3

# %%
limit(f(x),x=0)
# Out:
# 3

# %%
diff(f(x),x)
# Out:
# 4*x

# %%
plot([exp(x),x^2,2*x],x,-1,2)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
g1 = plot(x^2,x,-1.25,1.25)
g2 = plot(ln(x),x,0,1.9,color="green")
g3 = circle((0,0),2,color="red")
g4 = polygon([[1,2],[4,4],[4,0]])
show(g1+g2+g3,gridlines="minor")
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
var("t")
x(t)=t*cos(t); y(t)=t*sin(t)
parametric_plot((x(t),y(t)),(t,0,6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive
