# %%
E=1.25/3E14;E
# Out:
# 4.16666666666667e-15

# %%
E*1.6E-19
# Out:
# 6.66666666666667e-34

# %%
c=299792458;cc=n(c^2);cc
# Out:
# 8.98755178736818e16

# %%
1/cc
# Out:
# 1.11265005605362e-17

# %%
(1/cc)^2
# Out:
# 1.23799014723612e-34

# %%
6.626E-34/1.23799014723612e-34
# Out:
# 5.35222353327521

# %%
h=6.626E-34;hb=h/(2*n(pi));hb
# Out:
# 1.05456065292690e-34

# %%
hr=2.0^(1/13)*1E-34

# %%
1/(hb/hr)
# Out:
# 1.00019479539103

# %%
s=7.53E-19;f=3E+16 # s=seuil

# %%
E=h*f;E
# Out:
# 1.98780000000000e-17

# %%
2E-17>7.53E-19
# Out:
# True

# %%
Ec=E-s;Ec #Energie cinétique
# Out:
# 1.91250000000000e-17

# %%
1/Ec # Energie potentielle ?
# Out:
# 5.22875816993464e16

# %% [markdown]
# La lumière est de l'énergie potentielle, l'inverse de l'énergie cinétique, surtout pas la moitié
