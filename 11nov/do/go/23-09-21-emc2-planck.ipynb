# %% [markdown]
# ###### Analyse de célérité
#
# Einstein s'est trompé en nommant la fréquence angulaire vitesse de la lumière, célérité $c$.
#
# La vitesse de la lumière est apparu dans les équations de Maxwell, comme étant le raport $v=\frac{Em}{Qm}=c$.
#
# Ce qui est bizarre c'est que la résistance en E.s. donne le même résulat que la résistance en E.m, avec 2 opérations inverses :
#
# $\frac{1}{v^2}=\frac{T}{L}=\frac{L}{T}=\frac{1}{c^2}$
#
# Complètement erroné, une des raisons par laquelle je ne travaille pas avec les dimensions. D'après ces équations l'impédance du vide serait équivalente dans les 2 sens.

# %%
c=299792548;mu=n(pi)*4E-7;ep=1/(mu*c*c);T=mu;L=ep
Z=sqrt(T/L);Z,1/Z
# Out:
# (376.730426559106, 0.00265441793256141)
