# %%
import math 
math.degrees(1)
# Out:
# 57.29577951308232

# %%
math.radians(100)
# Out:
# 1.7453292519943295

# %% [markdown]
# import numpy as np
# @interact
# def _(E=('Energy [keV]', slider(1,1000,step_size=1))):
#     x=np.linspace(0,180,180)
#     for i in range(0,180):
#         E2=E/(1+E/511*(1-cos(x[i]/180*pi)))
#         x[i]=10*2.8179^2*(E2/E)^2*(E2/E+E/E2-sin(x[i]/180*pi))
#         list_plot((list)(x)).show(axes_labels=['$\Theta$', 'mb'])
