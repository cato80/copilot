# %% [markdown]
# ## Installation de python
#
# ### Pierre Proulx, 2016
#
# ### Dans ce document on regardera comment installer un environnement python complet incluant
#
#     # spyder , un environnement de développement (similaire à Matlab)
#
#     # jupyter notebook (anciennement appelé Ipython notebook), un outil permettant d'écrire des documents incorporant texte, math, graphique d'une façon inédite. Impressionnant!
#
#     # les 'packages' importants de python que sont scipy, numpy, sympy et matplotlib

# %% [markdown]
# ## Installer anaconda
#
# __aller sur https://www.continuum.io/downloads __
#
# Télécharger la version (python 3.5) qui correspond à votre système d'exploitation (Windoze, MacOS ou Linux)
#
# Les figures qui suivent vous guideront

# %% [markdown]
# ## Premièrement aller sur
# <img src='ana1.png'>
#
# ## Ensuite choisir
# <img src='ana2.png'>
#
# ## Vous pouvez aller voir comment charger les packages pendant le chargement
# <img src='ana3.png'>
#
# ## Et installer
# <img src='ana4.png'>

# %% [markdown]
# ### L'installation terminée, vous pouvez lancer anaconda qui vous montrera les packages installés:
#
# <img src='ana5.png'>

# %% [markdown]
# ## Dans l'exemple ci-dessus, l'environnement spyder, qui permet de développer des codes python, est déjà installé. Si on voulait ajouter des packages, on les ajouterait à partir de environments.
#
# ### spyder est installé avec les packages importants (scipy, numpy, matplotlib).
#
# ### La figure qui suit montre spyder, j'ai fait une modification aux préférences pour inclure le calcul symbolique au démarrage. (use symbolic math, calcul formel en français)
# <img src='ana6.png'>

# %% [markdown]
# ### Ainsi, la prochaine fois que j'utilise spyder, j'aurai directement accès à ceci en tapant quelques lignes dans la console Ipython. Remarquez qu'automatiquement on a déjà démarré sympy et fait quelques définitions de variables
#
#
# from sympy import *
# etc...
#
#
#
# <img src='ana7.png'>
#
# #### évidemment on peut faire beaucoup plus, ceci n'est qu'un ou deux exemples de calcul symbolique, comme on le fait facilement avec mupad sous Matlab.
