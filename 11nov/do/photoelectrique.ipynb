# %% [markdown]
# http://www.chimix.com/an4/an40/bts/photometrie.htm

# %% [markdown]
# corrigé :
#
# Isat et P sont proportionnelles
#
#  rendement quantique : n= n/N
#
# n : nombre électrons émis en Dt seconde ; N nombre photons capturés en Dt s
#
# n= I Dt / e avec e= 1,6 10-19 C
#
# N= Poptique Dt / ( h n) avec h n = 6,6 10-34 * 3 10 8 / 555 10-9)=3,56 10-19 J
#
# n = n/N= I hn / (Poptique e)=11 10-6*3,56 10-19 /(8 10-3 *1,6 10-19)=0,003.
#
# travail d'extraction : e Uarrêt = 1,6 10-19*1 = 1,6 10-19 J
#
# énergie du faisceau : h n = 3,56 10-19 J
#
# énergie cinétique des électrons émis : (3,56-1,6 ) 10-19 = 1,96 10-19 J
#
# vitesse : ½mv²= 1,96 10-19 avec m = 9 10-31 kg
#
# v²= 2*1,96 10-19/ 9 10-31 = 4,35 1011
#
# v= 6,6 105 m/s.

# %% [markdown]
# ###### Erreur !
#
# Les propriétés du photon :
#
# Sa masse au repos nulle. Sa charge électrique est nulle. Il se déplace dans le vide à la vitesse c = 3 ·108 m/s. Son énergie est : E = hn avec h = 6,62 10-34 Js. Or n =c/l.d'où E = hc/l avec l longueur d'onde ( en m) de l'onde électromagnétique associée au photon.

# %% [markdown]
# $h$ contient $2\pi$

# %%
0.511*2
# Out:
# 1.02200000000000

# %% [markdown]
# https://www.nuclear-power.com/nuclear-power/reactor-physics/atomic-nuclear-physics/fundamental-particles/beta-particle/positron-annihilation-2/
#
# ![image.png](attachment:image.png)
#
# longueur d’onde de photon de 1,2132 picomètre

# %% [markdown]
# https://en.wikipedia.org/wiki/Pair_production
#
# Le photon doit être près d’un noyau afin de satisfaire la conservation de la quantité de mouvement, car une paire électron-positon produite dans l’espace libre ne peut pas satisfaire à la fois la conservation de l’énergie et de la quantité de mouvement. [4] Pour cette raison, lorsque la production de paires se produit, le noyau atomique reçoit un certain recul. L’inverse de ce processus est l’annihilation électron-positron
