# %%
dr=x*pi/2;nr=plot(dr,x,0,1.047,color="red",linestyle="--")
ce=circle((0,0),2.85,color="red");ci=circle((0,0),2,color="black")
a1 = arc((0,0), 2.85, angle=pi/4,sector=(pi/4,1*pi/-4),thickness=2)
a2 = arc((0,0), 2, angle=pi/6,color="red",sector=(pi/-6,0.9*pi/6))
a3 = arc((0,0), 2, angle=pi/2.7,color="green",sector=(pi/8,1*pi/-8))

# %%
la=x*pi/pi;al=plot(la,x,0 ,2,color="blue",linestyle="--")
lb=text("\u2630",(2.4,2.6),color="blue",fontsize=18)
lt=text("$\\frac{\\pi}{4}:45^o $",(2.4,2.6),color="blue",fontsize=18)
li=text("$i$",(-0.2,2.5),color="red",fontsize=18)
show(ce+ci+a1+a2+a3+al+lt+li,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=5,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
p1=polygon(((-2,2),(2,2),(2,-2),(-2,-2)),color="cyan",alpha=0.2,
       thickness=1,frame=True,axes=True);
cv=circle((0,0),1,color="black");ci=circle((0,0),2,color="black")
show(cv+ce+ci+a1+a2+a3+al+lt+li+p1,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=10,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="salmon",alpha=0.1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="yellow",alpha=1)
show(a+b+ce+ci+a1+a2+a3+al+lt+li+p1,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=10,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
c2=circle((0,0),1.41,color="red")
p2=polygon(((-1.41,1.41),(1.41,1.41),(1.41,-1.41),(-1.41,-1.41)),
color="white",alpha=0.5,thickness=1,frame=True,axes=True)
show(cv+a+b+ce+ci+a1+a2+a3+al+lt+li+p1+p2+c2,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",gridlinesstyle=dict(color="orange",
linestyle="-",alpha=0.2),figsize=10,fontsize=8,
frame=False,axes=True)
# Out:
# Graphics object consisting of 16 graphics primitives

# %%
1*1.41
# Out:
# 1.41000000000000

# %%
1.4142/1.128
# Out:
# 1.25372340425532
