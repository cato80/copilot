# %% [markdown]
# 3/2 quinte=1.5
#
# La période (s) c'est la circonférence et la fréquence (hz) est le diamètre. La longueur d'onde est la valeur de la période en m.
# Longueur d'onde grande = fréquence faible

# %%
(1.5*106)
# Out:
# 159.000000000000

# %%
444/159.0
# Out:
# 2.79245283018868

# %% [markdown]
# voir impédance de l'air et impédance du vide
