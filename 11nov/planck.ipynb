# %%
c=299792458;f1=4.62E-14

# %%
l1=c/f1;l1
# Out:
# 6.48901424242424e21

# %% [markdown]
# violet 380-450
#
# bleu 450-495
#
# vert 495-570
#
# jaune 570-590
#
# orange 590-620

# %%
f0=c/450E-9;fb=c/495E-9;fb
# Out:
# 6.05641329292929e14

# %%
v=1.00052;vc=c/v;vc
# Out:
# 2.99636646943589e8

# %%
vc/fb # perte de lambda E-2
# Out:
# 4.94742733778435e-7

# %% [markdown]
# n=c/v donc v=c/n
#
# $n=\sqrt\mu\epsilon$
#
# $n=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{\sqrt\mu\epsilon}}=\frac{c}{v}=1$ dans le vide $1,00052$

# %%
show(LatexExpr(r"c=\frac{1}{\sqrt\mu\epsilon}=299792458"))
# Out:
# c=\frac{1}{\sqrt\mu\epsilon}=299792458

# %%
show(LatexExpr(r"ç=\frac{1}{\sqrt\mu\epsilon}=314159265"))
# Out:
# ç=\frac{1}{\sqrt\mu\epsilon}=314159265
