# %%
# %display latex
u(n) = n^100 / 100^n

# %%
u(2.);u(3.);u(4.);u(5.);u(6.);u(7.);u(8.);u(9.);u(10.)
# Out:
# 1.00000000000000e80

# %%
p=plot(u(x), x, 1, 40,thickness=0.5);
show(p,figsize=3,fontsize=5,frame=True);
# Out:
# /home/pi/.local/lib/python3.8/site-packages/sympy/core/function.py:107: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   evalargspec = inspect.getargspec(cls.eval)
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 1 graphics primitive

# %%
v(x) = diff(u(x), x); sol = solve(v(x) == 0, x); sol
# Out:
# [x == 50/log(10), x == 0]

# %%
floor(sol[0].rhs()),floor(sol[0].left())
# Out:
# (21, floor(x))

# %%
limit(u(n), n=infinity)
# Out:
# 0

# %%
n0 = find_root(u(n) - 1e-8 == 0, 22, 1000); n0
# Out:
# 105.07496210187252

# %%
find_root(sin(x)==x^2,0.5,1)
# Out:
# 0.8767262153950625

# %%
deg(x)=x*180/3.141592653;deg(0.78540)
# Out:
# 45.0001052380230

# %%
2.0/3.141592653
# Out:
# 0.636619772487098

# %%
deg(0.636619772487098)
# Out:
# 36.4756261249372

# %%
c=circle((0,0),1,color="black");o=point((0.5,0.868));
q=point((0.71,0.71));p=point((0.868,0.5));
show(c+p+q+o,gridlines="minor")
# Out:
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 4 graphics primitives

# %%
b=line([(0,0),(0.5,0.86)],color="blue",linestyle="--")
v=line([(0,0),(0.7,0.7)],color="green",linestyle="--")
r=line([(0,0),(0.86,0.5)],color="red",linestyle="--")
show(c+p+q+o+b+v+r,
gridlines="minor",figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
deg(x)=x*180/3.141592653;deg(1)
# Out:
# 57.2957795238389

# %%
rad(x)=x*3.141592653/180;rad(45)
# Out:
# 0.785398163250000

# %%
rad(x)=x*3.141592653/180;rad(30)
# Out:
# 0.523598775500000

# %%
i = CC.0;li=line([-i, 0.7+0.7*i])
show(c+li+v,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
i = CC.0;li=line([i, 0.7+0.7*i])
show(c+li+v,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
dE=1.25/4.1E-15;dE
# Out:
# 3.04878048780488e14

# %%
1/4.39E-14
# Out:
# 2.27790432801822e13

# %% [markdown]
# $\lambda=c/f=cT=ct$ et $\nu=1/T$

# %%
i = CC.0;li=line([-i, 0.7+0.7*i])
show(c+li,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
i = CC.0;li=line([1+i, 0.7+0.7*i])
show(li,figsize=5,gridlines="minor")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
i = CC.0;li=line([i+1, 0.7+0.7*i])
show(c+li+v,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
r=2.0/sqrt(3.141592653);cr=circle((0,0),r)
i = CC.0;li=line([i+1, 0.8+0.8*i])
show(cr+li+v,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
(0.8+0.8*i)^2
# Out:
# 1.28000000000000*I

# %%
po=polygon([(1,1),(-1,1),(-1,-1), (1,-1)],fill=False)
show(cr+li+v+po,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
(0.8+0.8*i)^2+i
# Out:
# 2.28000000000000*I

# %%
lii=line([i-1, (0.8+0.8*i)^2+i]);lii
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(cr+li+lii+v+po,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
i = CC.0;li=line([-i, 0.7+0.7*i])
show(c+li+v,figsize=5,gridlines="minor",
frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# E=hf dont h=6.628E-34 et e=1.60E-19
# f=1.5E+15 hz  E=hf=9.9E-19 J    E=6.2eV

# %%
h=6.628E-34;f=1.5E+15;ec=1.60E-19 
E=h*f;E
# Out:
# 9.94200000000000e-19

# %%
eV=E/ec;eV
# Out:
# 6.21375000000000

# %%
lo=6.00E-7;c=299792458
f=c/lo;Eh=h*(c/lo);Eh #Joule
# Out:
# 3.31170735270667e-19

# %%
Ev=Eh/ec;Ev
# Out:
# 2.06981709544167

# %%
1/Ev
# Out:
# 0.483134477052242

# %%
deg(x)=x*180.0/3.141592653;deg(1)
# Out:
# 57.2957795238389

# %%
deg(x)=x*180.0/3.141592653;deg(0.483134477052242)
# Out:
# 27.6815664775504
