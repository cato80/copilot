# %% [markdown]
# https://fr.wikipedia.org/wiki/Fr%C3%A9quence
#
# ![image.png](attachment:image.png)

# %%
# %display latex
var("a w t")
# Out:
# (a, w, t)

# %%
show(LatexExpr(r"z=ae^{iwt}=x+iy"))
# Out:
# z=ae^{iwt}=x+iy

# %%
n(e)
# Out:
# 2.71828182845905

# %%
2.99792458/n(e)
# Out:
# 1.10287481916453

# %%
2.99792458-n(e)
# Out:
# 0.279642751540955

# %%
ln(e)
# Out:
# 1

# %%
f=x^5+x^4+x^3+x^2+x
solve(f==1,x)
# Out:
# [0 == x^5 + x^4 + x^3 + x^2 + x - 1]

# %%
f=x^5+x^4+x^3+x^2+x
solve(f==0,x)
# Out:
# [x == -1/4*sqrt(5) - 1/2*sqrt(1/2*sqrt(5) - 5/2) - 1/4, x == -1/4*sqrt(5) + 1/2*sqrt(1/2*sqrt(5) - 5/2) - 1/4, x == 1/4*sqrt(5) - 1/2*sqrt(-1/2*sqrt(5) - 5/2) - 1/4, x == 1/4*sqrt(5) + 1/2*sqrt(-1/2*sqrt(5) - 5/2) - 1/4, x == 0]

# %%
f=x^5-x^4-x^3-x^2-x
solve(f==0,x)
# Out:
# [x == -1/12*sqrt(6)*sqrt((1/2)^(2/3)*(4*(1/2)^(2/3)*(3*sqrt(563)*sqrt(3) - 65)^(2/3) + 11*(1/2)^(1/3)*(3*sqrt(563)*sqrt(3) - 65)^(1/3) - 56)/(3*sqrt(563)*sqrt(3) - 65)^(1/3)) - 1/2*sqrt(-1/3*(1/2)^(1/3)*(3*sqrt(563)*sqrt(3) - 65)^(1/3) - 13/2*sqrt(6)*(1/2)^(2/3)/sqrt((4*(1/2)^(2/3)*(3*sqrt(563)*sqrt(3) - 65)^(2/3) + 11*(1/2)^(1/3)*(3*sqrt(563)*sqrt(3) - 65)^(1/3) - 56)/(3*sqrt(563)*sqrt(3) - 65)^(1/3)) + 28/3*(1/2)^(2/3)/(3*sqrt(563)*sqrt(3) - 65)^(1/3) + 11/6) + 1/4, x == -1/12*sqrt(6)*sqrt((1/2)^(2/3)*(4*(1/2)^(2/3)*(3*sqrt(563)*sqrt(3) - 65)^(2/3) + 11*(1/2)^(1/3)*(3*sqrt(563)*sqrt(3) - 65)^(1/3) - 56)/(3*sqrt(563)*sqrt(3) - 65)^(1/3)) + 1/2*sqrt(-1/3*(1/2)^(1/3)*(3*sqrt(563)*sqrt(3) - 65)^(1/3) - 13/2*sqrt(6)*(1/2)^(2/3)/sqrt((4*(1/2)^(2/3)*(3*sqrt(563)*sqrt(3) - 65)^(2/3) + 11*(1/2)^(1/3)*(3*sqrt(563)*sqrt(3) - 65)^(1/3) - 56)/(3*sqrt(563)*sqrt(3) - 65)^(1/3)) + 28/3*(1/2)^(2/3)/(3*sqrt(563)*sqrt(3) - 65)^(1/3) + 11/6) + 1/4, x == 1/12*sqrt(6)*sqrt((1/2)^(2/3)*(4*(1/2)^(2/3)*(3*
# ...

# %%
f=x^5-x^4-x^3-x^2-x
solve(f==1,x)
# Out:
# [0 == x^5 - x^4 - x^3 - x^2 - x - 1]

# %% [markdown]
# quintique=quinte=fa do sol re la et mi si

# %%
la=444;la2=888;
