# %%
# %display latex
cr=n(pi)/6;r=sqrt(2.0) # coudée royale
cc=439.995154 #base 440
lg=cr*r*n(pi)*439.995154;lg # cercle circonscrit en MHz
pg=cr*cc*n(pi);lg,pg
# Out:
# (1023.55547608840, 723.763018062732)

# %%
c=lg-pg;int(c*1000000000000)# micro mètres
# Out:
# 299792458025666

# %% [markdown]
# J'avais lu sur internet qu'on retrouvait la célérité dans la base d'une pyramide, certains critiquaient le calcul, alors j'ai voulu en avoir le coeur net !
#
# cr= coudée royale pi/6, cc=nombre de coudée pour la base(normalement 440 comme la fréquence du LA, mais ça manque de précisions, après un calcul j'ai trouvé : 439.995154 coudée royale, trop de précisions n'apporte pas une meilleure vue ?)
#
# r=racine carrée de 2
#
# lg=Cercle circonscrit :cr*r*pi*base
#
# pg=cr*pi*base
#
# La différence lg-pg=c
#
# Le rapport lg/pg=racine carrée de 2 =$\sqrt 2$

# %%
round((lg-pg)*1000000)^2
# Out:
# 89875517873681764

# %%
lg/pg
# Out:
# 1.41421356237310

# %% [markdown]
# On peut affirmer, conjecturer que c est le produit de coudée royale , $\pi$, $\sqrt 2$ et d'un carrée de côté de valeur cb
#
# En d'autres termes, $c$ est un carré encadré d'un cercle inscrit et d'un cercle circonscrit (sa valeur numèrique dépend de la précision de la base !)
#
# La preuve de la quadrature du cercle est $c$

# %%
p=polygon([(-0.5,0.5),(-0.5,-0.5),(-0.5,-0.5),
(0.5,-0.5),(0.5,0.5),(0.5,0.5)],
 color="black",fill=False)
ri=circle((0,0),sqrt(2.0)/2,color="red")
rc=circle((0,0),1/2,color="blue")
show(rc+ri+p,gridlines="minor",figsize=3,fontsize=4,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=False)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
show(rc+ri+p,gridlines="minor",figsize=3,fontsize=4,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=True,axes=False)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
r=2/sqrt(n(pi));
qc=circle((0,0),r/2,color="green")
show(rc+ri+p+qc,gridlines="minor",figsize=10,fontsize=4,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=True,axes=False)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# Le cercle vert est en quadrature avec le carré, même aire= 4 et périmètre =4, parce-que r=2+2 et r=2*2 ont un résultat identique !

# %%
Hz1=2*pi #rad/s

# %% [markdown]
# C'est le cercle inscrit dans un carré de 1

# %%
3.141592653/2.99792458
# Out:
# 1.04792251077911

# %%
rad(x)=x*n(pi)/180;rad(1)
# Out:
# 0.0174532925199433

# %%
(60*n(pi))/180
# Out:
# 1.04719755119660

# %%
sqrt(sqrt(1/(120*n(pi)/360))*10)
# Out:
# 3.12602786904698

# %% [markdown]
# L'impédance du vide, environ 120$\pi$ divisée par 360, donne la valeur d'une constante ç=1.04719755119660

# %%
t=((6.28/60)^2)/9.87;t
# Out:
# 0.00110994033547225

# %%
1.0/(299792458^2)
# Out:
# 1.11265005605362e-17

# %%
t/1E-20
# Out:
# 1.10994033547225e17

# %%
d=1.11265005605362/1.10994033547225

# %%
72/24
# Out:
# 3

# %%
1/((d-1)*3)
# Out:
# 136.538104470163

# %%
cr=n(pi)/6;r=sqrt(2.0) # coudée royale
cc=439.995154 #base 440
lg=cr*r*n(pi)*439.995154;lg # cercle circonscrit en MHz
pg=cr*cc*n(pi);lg,pg
rc=cr*r*n(pi)/439.995154;rc
# Out:
# 0.00528707656299845

# %%
rad(x)=x*n(pi)/180;rad(0.418)
# Out:
# 0.00729547627333630

# %%
1/rad(0.418)
# Out:
# 137.071242854264

# %%
co=cr*r*n(pi)/418;co
# Out:
# 0.00556528245585238

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823
