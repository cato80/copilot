# %% [markdown]
# #####  Let light be... Celerity and angular frequency
#
# Since 1905, date of Relativity, the same error has been reconducted, because the dogma of celerity !
#
# Einstein said that speed of light is a limit of maximum speed, no particles can reach or bypassed !
#
# I don't agree with that : Except maybe in one case, in a local relativistic space-time, which is not an universal space, but a local one !
#
# First I define what is a universal space : Space with no limit of any sort ! Infinity ! One can see it as a white transparency infinite aera, shining light ?. Perfect emptiness, perfect immobilty ! Does this exist ? Is it visible or invisible ?
#
# Back to earth : In maths, speed is a derivative not a constant : Celerity $c$ is a constant, then a constant has no derivative (constant=0) one can't called a constant a speed... Then c²=c.c is an acceleration and square root of an acceleration is not a speed either, from this $c$ can't be a speed !
#
# Back to c²: The origin of $c$ is $c^2$ then they just have calculated the square root. But that's not a mathematical result, it should be derivative as I said before :$2c$ !

# %%
show(LatexExpr("First \\ light \\ equation :"))
show(LatexExpr(r"\large c=\large \frac{1}{\sqrt\mu\epsilon}=299792458"))
# Out:
# First \ light \ equation :
# \large c=\large \frac{1}{\sqrt\mu\epsilon}=299792458

# %%
show(LatexExpr("Second \\ light \\ equation \\ angular \\ frequency \\ way:"))
show(LatexExpr(r"\large c=2\pi f=299792458=\omega"))
# Out:
# Second \ light \ equation \ angular \ frequency \ way:
# \large c=2\pi f=299792458=\omega

# %% [markdown]
# There is a resonance frequency

# %%
show(LatexExpr("Light \\ resonance \\ frequency :"))
show(LatexExpr(r"\large f_r=\frac{1}{2\pi\sqrt\mu\epsilon}=47713451Hz"))
# Out:
# Light \ resonance \ frequency :
# \large f_r=\frac{1}{2\pi\sqrt\mu\epsilon}=47713451Hz

# %% [markdown]
# It's just for info at the time I haven't seen it used anywhere ?

# %% [markdown]
# Up to now nothing new in the west ! That's scientific ideology. Now I present my conterpart :
#
# Light as an angulary frequency (Here is the miracle...) in my way :
#
# $\mu$ becomes L (Inductance,voltage) in H (Henry) and $\epsilon$ becomes C (capacitance, intensity) the ratio of both is resistance, Impedance in alternative current), but with a particular frequency which suits to my concept !

# %%
L=1/n(pi)*360E-8;C=1/(n(pi)*360E+8)
show(LatexExpr("Equation   \\ of \\ angulary \\ frequency \\ chiracécity (ç):"))
show(LatexExpr(r"\large ç=\large \frac{1}{\sqrt\mu\epsilon}=314159265.3"))
show(LatexExpr(r"\large ç=\large \frac{1}{\sqrt L C}=314159265.3"))
show(LatexExpr(r"\large f_r=\frac{1}{2\pi\sqrt\mu\epsilon}=50000000Hz"))
# Out:
# Equation   \ of \ angulary \ frequency \ chiracécity (ç):
# \large ç=\large \frac{1}{\sqrt\mu\epsilon}=314159265.3
# \large ç=\large \frac{1}{\sqrt L C}=314159265.3
# \large f_r=\frac{1}{2\pi\sqrt\mu\epsilon}=50000000Hz

# %%
round(n(pi)*1E+8/(2*n(pi)))
# Out:
# 50000000

# %%
Fr2=round(n(pi)*1E+8/(2*n(pi)))*2;Fr2
# Out:
# 100000000

# %% [markdown]
# This last result is very important =0.1 billions (0.1 m).
# But I haven't yet all analyse ?
#
# Surprising results from this :
#
# An angulary frequency is in rad/s, then the ratio between $ç/c$ is 60°/30°
#
# A square, basis of 440 (Precision439.99) with circumscribed circle and inscribed, difference egual $c$

# %%
rp=314159265.3/299792458;rp
# Out:
# 1.04792251077911

# %%
deg(x)=x*180/n(pi);deg(1.04792251077911) # 60 °
# Out:
# 60.0415371243955

# %%
c=n(pi)/6;r=sqrt(2.0);cp=c*r*n(pi)*439.995154;cp
# Out:
# 1023.55547608840

# %%
cr=n(pi)/6;rp=c*n(pi)*440;rp
# Out:
# 723.770989413219

# %%
cc=439.995154;lc=cr*cc*n(pi);ll=cr*cc*r*n(pi);ll-lc
# Out:
# 299.792458025667

# %% [markdown]
# I would dare say it suits better in Mhz, than Mm ?

# %%
# %display latex
ce=circle((0,0),3,color="red");a1=arc((0,0),3,angle=pi/4, 
sector=(pi/4,pi/-4),thickness=1)
show(ce+a1,gridlines="minor",figsize=3,fontsize=4,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives
