# %% [markdown]
# ##### Ether, lumière, espace
#
# L'espace est l'intervalle entre alpha et omega. C'est le rapport entre l'éther,impédance du vide, et  la lumière conductance.

# %%
# %display latex
Cç=(n(pi*2,digits=18));Cç # 2 pi Nombre d'électrons 1 coulomb
# Out:
# 6.28318530717958648

# %%
Cc=6.28318530717958648E18;Cc,1/Cc
# Out:
# (6.2831853071795865e18, 1.5915494309189534e-19)

# %%
Jç=1/Cç*1E-18;Jç
# Out:
# 1.59154943091895e-19

# %%
Jc=1/Cc;Jc
# Out:
# 1.5915494309189534e-19
