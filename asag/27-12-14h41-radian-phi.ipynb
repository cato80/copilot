# %%
# %display latex
f(x)=x^2-x-1;solve(f==0,x)
# Out:
# [x == -1/2*sqrt(5) + 1/2, x == 1/2*sqrt(5) + 1/2]

# %%
f=x^2-x-1;solve(f==1,x)
# Out:
# [x == 2, x == -1]

# %%
ra=x^3-x-1;solve(ra==5,x)
# Out:
# [x == -I*sqrt(2) - 1, x == I*sqrt(2) - 1, x == 2]

# %%
(i*sqrt(2.0)-1)*(-i*sqrt(2.0)-1)
# Out:
# 3.00000000000000

# %% [markdown]
# 1 pied = 12 pouces = 16 doigts = 144 lignes
#
# 36 72 144 x10 x100 vitesse du son 1224kh
#
# Le son est la compression de l'éther de a b, l'éther est une impédance donc le son à une tension et une intensité, ce rapport est en degré.
#
# 144000/3600

# %%
1440/60==24
# Out:
# True

# %%
40*3600
# Out:
# 144000
