# %%
# %display latex
factorial(1/2)
# Out:
# 1/2*sqrt(pi)

# %%
ç=1/(sqrt(n(pi)));ç
# Out:
# 0.564189583547756

# %%
c=sqrt(n(pi))/4;c
# Out:
# 0.443113462726379

# %%
1/factorial(1/2)
# Out:
# 2/sqrt(pi)

# %% [markdown]
# La quadrature du cercle peut être calculée de 2 façons, avec la factorielle et son inverse.

# %%
ç*c
# Out:
# 1.00000000000000
