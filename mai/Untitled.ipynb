# %% [markdown]
# $lambda = \frac{c}{\nu} = 2\pi R \quad \Rightarrow \quad R = \frac{c}{2\pi\nu}$
#
# $ℏS = \frac{h\nu}{c} \cdot \frac{c}{2\pi\nu} \quad \Rightarrow \quad S = \frac{h}{2\pi} = \hbar$
#
# $\lambda = \frac{c}{\nu} = 2\pi R \implies R = \frac{c}{2\pi\nu} $
