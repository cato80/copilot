# %%
Ll = text("$L=\\frac{\\hbar}{2}$", (0, 1.1), color="red", 
fontsize=12,);Ep=ellipse((0,1.2),0.2,0.07,color="green")
hbar=1.054E-34
L=hbar/2 #(0.5 vertical centré)
#R=1 ligne rouge et Rr=1 radian arc de cercle bleu
f=sqrt(1-(x^2));d=plot(-f,x,-1,1,color="red")
x1=x*1.72;y1=plot(x1,x,0,0.5,linestyle="-",color="red");
l = line(((0,0), (cos(pi/6+pi/2),2*sin(pi/6+pi/2))),
color="red", linestyle="dashed");ci=circle((0,0),1)
ld=line([[0.5,0],[0.5,0.87]],color="green")
lht = text("ht", ( 0.5, 0.5), color="green", 
fontsize=12,);El=ellipse((0, 0),1,0.299,color="red")
#ht hauteur en vert 
x2=x/1024;y2=plot(x2,x,0,1,color="blue",linestyle="-")
Rl = text("R", (0.2, 0.6), color="red", fontsize=10)
#p1=points([0.57,1]);p2=points([0.96,0.57],color="blue")
# r= rayon R=r, c=299792458 diamètre 2 r+r
Rr = text("Rr", (0.7, 0.8), color="blue", fontsize=10)
r = text("r", (0.4, 0.1), color="blue", fontsize=10)
c = text("c=299792458", (-0.4, -0.1), color="red", 
         fontsize=10)
ç = text("ç=314159245", (-0.001, -0.85), color="blue", 
         fontsize=10)
show(c+ci+y1+y2+ld+lht+Rl+Rr+r+Ll+El+ç+Ep,figsize=5,aspect_ratio=1,
fontsize=5,axes=True,gridlines="minor",frame=True)
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
num_value = 1.4142 / 2
from math import sqrt,radians
# Calcul des nouvelles coordonnées du point d'intersection pour un angle de 45 degrés
theta_new_radians = asin(num_value)
x_intersect_new = cos(theta_new_radians)
y_intersect_new = sin(theta_new_radians)

# Nouvelles coordonnées pour un angle de 42 degrés
theta_60_degrees = 60
theta_60_radians = radians(theta_60_degrees)
x_intersect_57 = cos(theta_60_radians)
y_intersect_57 = sin(theta_60_radians)

# Création du graphique
c = circle((0, 0), 1, color='green')  # Tracer le cercle vert
p = point((x_intersect_new, y_intersect_new), size=20, 
          color='blue')  # Tracer le point sur le cercle en utilisant les coordonnées polaires
l_60 = line([(0,0), (x_intersect_new, y_intersect_new)],
            color='red')  # Tracer la ligne rouge pour l'angle de 45 degrés
l_57 = line([(0,0), (x_intersect_57, y_intersect_57)], 
            color='blue')  # Tracer la ligne bleue pour l'angle de 42 degrés
t = text('[%.2f, %.2f]' % (x_intersect_new, y_intersect_new),
(x_intersect_new + 0.1, y_intersect_new + 0.1), 
         fontsize=6, color='black')  # Ajouter un texte à côté du point bleu
s_57 = text('57°', (0.4, 0.57), rotation=57,
            fontsize=8, color='red')  # Ajouter un texte "45°" sur le graphique en rouge
s_60 = text('60°', (0.4, 0.8), rotation=60, fontsize=8, 
            color='blue')  # Ajouter un texte "42°" sur le graphique en bleu

# Afficher le graphique avec les élém
show(c + p + l_60 + l_57 + t + s_60 + s_57, 
     axes_labels=['$x$', '$y$'], aspect_ratio=1, 
     fontsize=5, frame=True, gridlines="minor")
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
show(c+ci+y1+y2+ld+lht+Rl+Rr+r+Ll+El+ç+Ep,figsize=5,aspect_ratio=1,
fontsize=5,axes=True,gridlines="minor",frame=True)
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
num_value = 1.4142 / 2
from math import cos, sin, asin, radians
# Calcul des nouvelles coordonnées du point d'intersection pour un angle de 45 degrés
theta_new_radians = asin(num_value)
x_intersect_new = cos(theta_new_radians)
y_intersect_new = sin(theta_new_radians)
# Nouvelles coordonnées pour un angle de 60 degrés
theta_60_degrees = 60
theta_60_radians = radians(theta_60_degrees)
x_intersect_60 = cos(theta_60_radians)
y_intersect_60 = sin(theta_60_radians)
# Nouvelles coordonnées pour un angle de 57.7 degrés
theta_57_7_degrees = 57
theta_57_7_radians = radians(theta_57_7_degrees)
x_intersect_57_7 = cos(theta_57_7_radians)
y_intersect_57_7 = sin(theta_57_7_radians)
# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
#p_new = point((x_intersect_new, y_intersect_new), size=20, 
#              color='blue')  # Tracer le point sur le cercle en utilisant les coordonnées polaires
p60 = point((x_intersect_60, y_intersect_60), size=20, 
             color='black')  # Tracer le point sur le cercle pour un angle de 60 degrés
p57 = point((x_intersect_57_7, y_intersect_57_7), size=20, 
               color='black')  # Tracer le point sur le cercle pour un angle de 57.7 degrés
l_60 = line([(0,0), (x_intersect_60, y_intersect_60)],
            color='red',linestyle=":")  # Tracer la ligne rouge
l_57 = line([(0,0), (x_intersect_57_7, y_intersect_57_7)],
            color='blue',linestyle=":")  # Tracer la ligne rougepour l'angle de 45 degrés
t = text('[%.2f, %.2f]' % (x_intersect_new, y_intersect_new),
         (x_intersect_new + 0.1, y_intersect_new + 0.1), 
         fontsize=6, color='black')  # Ajouter un texte à côté du point bleu
s_60 = text('60°', (0.4, 0.8), rotation=60, fontsize=8,
            color='red')  # Ajouter un texte "45°" sur le graphique en rouge
s_57 = text('57.7°', (0.35, 0.42), rotation=57, fontsize=8,
            color='blue')  # Ajouter un texte "42°" sur le graphique en bleu
show(c+ci+y1+y2+ld+lht+Rl+Rr+r+Ll+El+ç+Ep+l_60+l_57+s_60+s_57+p60+p57,
figsize=5,aspect_ratio=1,fontsize=5,axes=True,gridlines="minor",frame=True)
# Out:
# Graphics object consisting of 19 graphics primitives

# %%
show(c+ l_60 + l_57  + s_60 + s_57, 
     axes_labels=['$x$', '$y$'], aspect_ratio=1, 
     fontsize=5, frame=True, gridlines="minor")
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
show(c+ci+y1+y2+ld+lht+Rl+Rr+r+Ll+El+ç+Ep+l_60+l_57+s_60+s_57+p60+p57,
figsize=5,aspect_ratio=1,fontsize=5,axes=True,gridlines="minor",frame=True)
# Out:
# Graphics object consisting of 19 graphics primitives

# %%
num_value = 1.4142 / 2
from math import cos, sin, asin, radians

# Calcul des nouvelles coordonnées du point d'intersection pour un angle de 45 degrés
theta_new_radians = asin(num_value)
x_intersect_new = cos(theta_new_radians)
y_intersect_new = sin(theta_new_radians)

# Nouvelles coordonnées pour un angle de 60 degrés
theta_60_degrees = 60
theta_60_radians = radians(theta_60_degrees)
x_intersect_60 = cos(theta_60_radians)
y_intersect_60 = sin(theta_60_radians)

# Nouvelles coordonnées pour un angle de 57.7 degrés (1 radian)
theta_57_7_degrees = 57.7
theta_57_7_radians = radians(theta_57_7_degrees)
x_intersect_57_7 = cos(theta_57_7_radians)
y_intersect_57_7 = sin(theta_57_7_radians)

# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p60 = point((x_intersect_60, y_intersect_60), size=20, 
             color='black')  # Tracer le point sur le cercle pour un angle de 60 degrés
p57 = point((x_intersect_57_7, y_intersect_57_7), size=20, 
               color='black')  # Tracer le point sur le cercle pour un angle de 57.7 degrés
l_60 = line([(0,0), (x_intersect_60, y_intersect_60)],
            color='red', linestyle=":")  # Tracer la ligne rouge pour l'angle de 60 degrés
l_57 = line([(0,0), (x_intersect_57_7, y_intersect_57_7)],
            color='blue', linestyle="--")  # Tracer la ligne bleue en pointillés pour l'angle de 57.7 degrés
ht = line([(0,0), (x_intersect_60, y_intersect_60)],
            color='green')  # Ligne verte positionnée sur l'angle de 60 degrés (ou 57.7 degrés si nécessaire)

s_60 = text('60°', (0.4, 0.8), rotation=60, fontsize=8,
            color='red')  # Ajouter un texte "60°" sur le graphique en rouge
s_57 = text('57.7°', (0.35, 0.42), rotation=57.7, fontsize=8,
            color='blue')  # Ajouter un texte "57.7°" sur le graphique en bleu

show(c + p60 + p57 + l_60 + l_57 + ht + s_60 + s_57,
     figsize=5, aspect_ratio=1, fontsize=5, axes=True, gridlines="minor", frame=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
from math import cos, sin, radians

# Conversion de l'angle en radians
theta_1_radian = 1
theta_1_degrees = radians(theta_1_radian)

# Calcul des coordonnées du point sur le cercle pour un angle d'un radian
x_intersect_1 = cos(theta_1_degrees)
y_intersect_1 = sin(theta_1_degrees)

# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p1 = point((x_intersect_1, y_intersect_1), size=20, 
           color='black')  # Tracer le point sur le cercle pour un angle de 1 radian

show(c + p1, figsize=5, aspect_ratio=1, fontsize=5, axes=True, gridlines="minor", frame=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
from math import cos, sin, radians

# Conversion de l'angle en radians
theta_1_radian = 1
theta_1_degrees = radians(theta_1_radian)

# Calcul des coordonnées du point sur le cercle pour un angle d'un radian
x_intersect_1 = cos(theta_1_degrees)
y_intersect_1 = sin(theta_1_degrees)

# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p1 = point((x_intersect_1, y_intersect_1), size=20, 
           color='black')  # Tracer le point sur le cercle pour un angle de 1 radian

show(c + p1, figsize=5, aspect_ratio=1, fontsize=5, axes=True, gridlines="minor", frame=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
from math import cos, sin, pi

# Conversion de l'angle en radians
theta_1_radian = 1
theta_1_degrees = theta_1_radian * (180 / pi)

# Calcul des coordonnées du point sur le cercle pour un angle d'un radian
x_intersect_1 = cos(theta_1_radian)
y_intersect_1 = sin(theta_1_radian)

# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p1 = point((x_intersect_1, y_intersect_1), size=20, 
           color='black')  # Tracer le point sur le cercle pour un angle de 1 radian

show(c + p1, figsize=5, aspect_ratio=1, fontsize=5, axes=True, gridlines="minor", frame=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
from math import cos, sin, asin, radians, pi

# Calcul des coordonnées pour un angle de 1 radian
theta_1_radian = 1
x_intersect_1 = cos(theta_1_radian)
y_intersect_1 = sin(theta_1_radian)

# Calcul des coordonnées pour un angle de 60 degrés
theta_60_degrees = 60
theta_60_radians = radians(theta_60_degrees)
x_intersect_60 = cos(theta_60_radians)
y_intersect_60 = sin(theta_60_radians)

# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p60 = point((x_intersect_60, y_intersect_60), size=20, color='black')  # Point pour 60 degrés
p1 = point((x_intersect_1, y_intersect_1), size=20, color='black')  # Point pour 1 radian
l_ht_60 = line([(0, 0), (x_intersect_60, y_intersect_60)], color='green', linestyle=':')  # Ligne ht sur 60 degrés
l_ht_1 = line([(0, 0), (x_intersect_1, y_intersect_1)], color='green', linestyle=':')  # Ligne ht sur 1 radian

show(c + p60 + p1 + l_ht_60 + l_ht_1, figsize=5, aspect_ratio=1, fontsize=5, axes=True, gridlines="minor", frame=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
from math import cos, sin, pi

# Calcul des coordonnées pour un angle de 1 radian
theta_1_radian = 1
x_intersect_1 = cos(theta_1_radian)
y_intersect_1 = sin(theta_1_radian)

# Création du graphique
c = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p1 = point((x_intersect_1, y_intersect_1), size=20, color='black')  # Point pour 1 radian
l_ht = line([(x_intersect_1, y_intersect_1), 
             (x_intersect_1, 0)], color='orange',linestyle=":")  # Ligne ht

show(c + p1 + l_ht, figsize=5, aspect_ratio=1, fontsize=5, axes=True, gridlines="minor", frame=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
num_value = 1.4142 / 2
ci=circle((0,0),1)
from math import cos, sin, asin, radians
# Calcul des nouvelles coordonnées du point d'intersection pour un angle de 45 degrés
theta_new_radians = asin(num_value)
x_intersect_new = cos(theta_new_radians)
y_intersect_new = sin(theta_new_radians)
# Nouvelles coordonnées pour un angle de 60 degrés
theta_60_degrees = 60
theta_60_radians = radians(theta_60_degrees)
x_intersect_60 = cos(theta_60_radians)
y_intersect_60 = sin(theta_60_radians)
# Nouvelles coordonnées pour un angle de 57.7 degrés
theta_57_7_degrees = 57
theta_57_7_radians = radians(theta_57_7_degrees)
x_intersect_57_7 = cos(theta_57_7_radians)
y_intersect_57_7 = sin(theta_57_7_radians)
# Création du graphique
c = text("c=299792458", (-0.4, -0.1), color="red", 
         fontsize=10)
lc = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
#p_new = point((x_intersect_new, y_intersect_new), size=20, 
#              color='blue')  # Tracer le point sur le cercle en utilisant les coordonnées polaires
p60 = point((x_intersect_60, y_intersect_60), size=20, 
             color='black')  # Tracer le point sur le cercle pour un angle de 60 degrés
p57 = point((x_intersect_57_7, y_intersect_57_7), size=20, 
               color='black')  # Tracer le point sur le cercle pour un angle de 57.7 degrés
l_60 = line([(0,0), (x_intersect_60, y_intersect_60)],
            color='red',linestyle=":")  # Tracer la ligne rouge
l_57 = line([(0,0), (x_intersect_57_7, y_intersect_57_7)],
            color='blue',linestyle=":")  # Tracer la ligne rougepour l'angle de 45 degrés
t = text('[%.2f, %.2f]' % (x_intersect_new, y_intersect_new),
         (x_intersect_new + 0.1, y_intersect_new + 0.1), 
         fontsize=6, color='black')  # Ajouter un texte à côté du point bleu
s_60 = text('60°', (0.4, 0.8), rotation=60, fontsize=8,
            color='red')  # Ajouter un texte "45°" sur le graphique en rouge
s_57 = text('57.7°', (0.35, 0.42), rotation=57, fontsize=8,
            color='blue') 
# Ajouter un texte "42°" sur le graphique en bleu
lht = text("ht", ( 0.5, 0.5), color="red", fontsize=12,);
l_ht = line([(x_intersect_1, y_intersect_1), 
             (x_intersect_1, 0)], color='blue',linestyle=":") 
show(c+ci+y1+y2+ld+lc+l_ht+lht+Rl+Rr+r+Ll+El+ç+Ep+l_60+l_57+s_60+s_57+p60+p57,
figsize=5,aspect_ratio=1,fontsize=5,axes=True,gridlines="minor",frame=True)
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
60/deg(1)
# Out:
# 1.04719755119660

# %%
314159265.3/299792458
# Out:
# 1.04792251077911

# %%
(314159265.3/299792458)/(60/deg(1))
# Out:
# 1.00069228540659

# %%
num_value = 1.4142 / 2
ci = circle((0,0),1)
from math import cos, sin, asin, radians
# Calcul des nouvelles coordonnées du point d'intersection pour un angle de 45 degrés
theta_new_radians = asin(num_value)
x_intersect_new = cos(theta_new_radians)
y_intersect_new = sin(theta_new_radians)
# Nouvelles coordonnées pour un angle de 60 degrés
theta_60_degrees = 60
theta_60_radians = radians(theta_60_degrees)
x_intersect_60 = cos(theta_60_radians)
y_intersect_60 = sin(theta_60_radians)
# Nouvelles coordonnées pour un angle de 57.7 degrés
theta_57_7_degrees = 57
theta_57_7_radians = radians(theta_57_7_degrees)
x_intersect_57_7 = cos(theta_57_7_radians)
y_intersect_57_7 = sin(theta_57_7_radians)
# Création du graphique
c = text("c=299792458", (-0.4, -0.1), color="red", 
         fontsize=10)
lc = circle((0, 0), 1, color='green', linestyle='-')  # Tracer le cercle vert
p60 = point((x_intersect_60, y_intersect_60), size=20, 
             color='black')  # Tracer le point sur le cercle pour un angle de 60 degrés
p57 = point((x_intersect_57_7, y_intersect_57_7), size=20, 
               color='black')  # Tracer le point sur le cercle pour un angle de 57.7 degrés
l_60 = line([(0,0), (x_intersect_60, y_intersect_60)],
            color='red',linestyle=":")  # Tracer la ligne rouge
l_57 = line([(0,0), (x_intersect_57_7, y_intersect_57_7)],
            color='blue',linestyle=":")  # Tracer la ligne rougepour l'angle de 45 degrés
t = text('[%.2f, %.2f]' % (x_intersect_new, y_intersect_new),
         (x_intersect_new + 0.1, y_intersect_new + 0.1), 
         fontsize=6, color='black')  # Ajouter un texte à côté du point bleu
s_60 = text('60°', (0.4, 0.8), rotation=60, fontsize=8,
            color='red')  # Ajouter un texte "45°" sur le graphique en rouge
s_57 = text('57.7°', (0.35, 0.42), rotation=57, fontsize=8,
            color='blue') 
# Ajouter un texte "42°" sur le graphique en bleu
lht = text("ht", ( 0.5, 0.5), color="red", fontsize=12,);
l_ht = line([(x_intersect_1, y_intersect_1), 
             (x_intersect_1, 0)], color='blue',linestyle=":") 
show(c+ci+y1+y2+ld+lc+l_ht+lht+Rl+Rr+r+Ll+El+ç+Ep+l_60+l_57+s_60+s_57+p60+p57,
figsize=5,aspect_ratio=1,fontsize=5,axes=True,gridlines="minor",frame=True)
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
deg(x)=x*180/n(pi);deg(1)
# Out:
# 57.2957795130823

# %%
rad(x)=x*n(pi)/180;rad(60)
# Out:
# 1.04719755119660

# %%
60/57.2957795130823
# Out:
# 1.04719755119660

# %%
dg= 42;deg(x)=x*180/n(pi);rad(x)=x*n(pi)/180;x = 1;y = x * tan(rd)
rd= rad(dg)
p = points([(0,0), (x,y)], size=30, color='blue', 
           axes_labels=['$x$', '$y$'])
l = line([(0,0), (x,y)], linestyle='dashed', 
         color='red', legend_label='oc=42°')
show(p + l,figsize=4,frame=True,axes=False)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
xc=1;yc=0;xi=xc;yi=xc*tan(rd);c=circle((0, 0),1,color='blue');adg=42
t=text('[%.2f, %.2f]'%(xi, yi),(xi-0.2,yi-0.1),fontsize=6,color='black') 
formula=r'$\theta_c=\sin^{-1}\left(\frac{1.00}{1.49}\right)$$=\sin^{-1}(0.671)= 42,2\degree$'
f = text(formula, (0.1, -0.2), fontsize=12, color='blue')
p = point((cos(rd), sin(rd)),size=30, color='black')
l = line([(0,0),(0.76,0.69)],linestyle='dashed',color='red')
s = text('42°', (0.38, 0.43),rotation=45,fontsize=8,color='red')
show(c+p+l+s+f+t,axes_labels=['$x$','$y$'],aspect_ratio=1,axes=True,
figsize=7,frame=True,fontsize=6)
# Out:
# Graphics object consisting of 6 graphics primitives
