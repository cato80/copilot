# %%
# Définition des constantes
MeV_to_Joules = 1.602176634e-13  # Conversion MeV en joules
MeV = 550  # Valeur en MeV

# Conversion de MeV en joules
E_joules = MeV * MeV_to_Joules

# Temps en secondes (à titre d'exemple, vous devriez spécifier le temps réel)
temps_seconde = 1

# Calcul de la puissance en watts
puissance_watts = E_joules / temps_seconde

print("Énergie en joules:", E_joules)
print("Puissance en watts:", puissance_watts)
# Out:
# Énergie en joules: 8.81197148700000e-11
# Puissance en watts: 8.81197148700000e-11

# %%
299792458^2
# Out:
# 89875517873681764

# %%
# Définition des constantes
MeV_to_Joules = # Définition des constantes
MeV_to_Joules = 1.602176634e-13  # Conversion MeV en joules
MeV = 550  # Valeur en MeV

# Conversion de MeV en joules
E_joules = abs(MeV) * MeV_to_Joules  # Utilisation de la valeur absolue pour s'assurer que MeV est positif

# Temps en secondes (à titre d'exemple, vous devriez spécifier le temps réel)
temps_seconde = 1

# Calcul de la puissance en watts
puissance_watts = E_joules / temps_seconde

print("Énergie en joules:", E_joules)
print("Puissance en watts:", puissance_watts)
  # Conversion MeV en joules
MeV = 550  # Valeur en MeV

# Conversion de MeV en joules
E_joules = abs(MeV) * MeV_to_Joules  # Utilisation de la valeur absolue pour s'assurer que MeV est positif

# Temps en secondes (à titre d'exemple, vous devriez spécifier le temps réel)
temps_seconde = 1

# Calcul de la puissance en watts
puissance_watts = E_joules / temps_seconde

print("Énergie en joules:", E_joules)
print("Puissance en watts:", puissance_watts)
# Out:
# Énergie en joules: 8.81197148700000e-11
# Puissance en watts: 8.81197148700000e-11
