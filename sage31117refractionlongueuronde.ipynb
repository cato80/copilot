# %% [markdown]
# An de grâce 2017, vendredi 3 novembre
#
# ##### Réfraction
#
# La réfraction de l'air est très importante, calculée ci-après
#
# n = indice de réfraction de l'air idéal (sous multiple de $c$, c'est une erreur de dire qu'elle est sensiblement égale à celle du vide : -88 km/s

# %%
r=299792458/1.000299792458;int(r)
# Out:
# 299702609

# %%
cr=299792458-r;print"n:1.000299792458  = ",(cr)
# Out:
# n:1.000299792458  =  89848.5819464326

# %%
sqrt(cr)
# Out:
# 299.747530342508

# %%
int(1.000299792458*1000000000000)
# Out:
# 1000299792457

# %% [markdown]
# La résistance du milieu (ou impédance) nous donne une précieuse indication en ohm/degré. Elle permet de rendre compte de l'éther. L'éther est donc l'impédance du vide :
#
# Ether = Z =3.76.96 ohms, ce n 'est qu'une question de terminalogie, l'éther a été malheureusement oculté par le terme champ (field) qui ne permet plus de calculer son existence même ! Le rapport du champ électromagnétique ($E/B$) égale l'éther. Toute une partie de la vitesse angulaire n'apparait pas dans Z, par contre elle apparait dans mon estimation de l'éther de 360 Ohms ou degrés.
#
# La fréquence de la lumière est ainsi plus importante et rejoint la valeur de $pi$ = 314159265
#
# La lumière et $\pi$ sont une seule et même chose !
#
# J'ai changé la valeur de $\mu$ et $\epsilon$ pour l'adapter aux valeurs réelles, ainsi que positivé la lumière car la lumière scientifique est négative = $ict$ au carré = "-1ct" et comme le supposait Fresnel, 2 rayons de lumières opposées donne le noir, s'annule = 0.

# %%
u=n(1/pi*360E-8);u
# Out:
# 1.14591559026165e-6

# %%
s=n(1/(pi*360E+8));s
# Out:
# 8.84194128288307e-12

# %%
ir=sqrt(u*s);ir
# Out:
# 3.18309886183791e-9

# %%
pir=sqrt(1/(u*s));int(pir)
# Out:
# 314159265

# %%
pir/299792458.0
# Out:
# 1.04792251097584

# %%
31.415/29.979
# Out:
# 1.04790019680443
